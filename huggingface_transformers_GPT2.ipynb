# %% [markdown]
# <a href="https://colab.research.google.com/github/tset-tset-tset/hoge/blob/master/huggingface_transformers_GPT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://huggingface.co/transformers/installation.html

# %%
# !git clone https://github.com/huggingface/transformers.git
# !cd transformers/; pip install -e .
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 43012, done.
# remote: Total 43012 (delta 0), reused 0 (delta 0), pack-reused 43012
# Receiving objects: 100% (43012/43012), 30.77 MiB | 15.21 MiB/s, done.
# Resolving deltas: 100% (29783/29783), done.
# Obtaining file:///content/transformers
# ...
#      |████████████████████████████████| 3.0MB 8.0MB/s
# ...
#      |████████████████████████████████| 1.1MB 49.8MB/s
# ...
#      |████████████████████████████████| 890kB 64.4MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=478a762b11e49e9ac0a853115bf5572417023f2c166fb84642b0b08f80697db2
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#   Running setup.py develop for transformers
# ...

# %%
# !gdown https://drive.google.com/uc?id=1KT4P31peQWuYFvOCfU39dYzLmtBDXUu2
# !head -n1000 original.txt > eval.txt
# !tail -n+1001 original.txt > train.txt
# !wc -l *.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KT4P31peQWuYFvOCfU39dYzLmtBDXUu2
# To: /content/original.txt
# 100% 734k/734k [00:00<00:00, 96.4MB/s]
#    1000 eval.txt
#   64626 original.txt
#   63626 train.txt
#  129252 total

# %% [markdown]
# https://www.tensorflow.org/tensorboard/tensorboard_in_notebooks

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# https://github.com/huggingface/transformers/blob/master/examples/language-modeling/run_language_modeling.py

# %%
## 初回実行、まだチェックポイントが無い場合
# !python transformers/examples/language-modeling/run_language_modeling.py \
    --output_dir=output_gpt2 \
    --model_type=gpt2 \
    --model_name_or_path=gpt2 \
    --do_train \
    --train_data_file=train.txt \
    --do_eval \
    --eval_data_file=eval.txt \
    --per_device_train_batch_size=2 \
    --per_device_eval_batch_size=2 \
    --num_train_epochs=10 \
    --save_steps=5000 \
    --save_total_limit=3

## 以前のチェックポイントを継続する場合
#!python transformers/examples/language-modeling/run_language_modeling.py \
#    --output_dir=output_gpt2 \
#    --model_type=gpt2 \
#    --model_name_or_path=output_gpt2 \
#    --overwrite_output_dir \
#    --do_train \
#    --train_data_file=train.txt \
#    --do_eval \
#    --eval_data_file=eval.txt \
#    --per_device_train_batch_size=2 \
#    --per_device_eval_batch_size=2 \
#    --num_train_epochs=10 \
#    --save_steps=5000 \
#    --save_total_limit=3
# Out:
# 2020-09-22 08:50:13.541922: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 09/22/2020 08:50:16 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# ...

# %% [markdown]
# https://github.com/huggingface/transformers/blob/master/examples/text-generation/run_generation.py

# %%
# !python transformers/examples/text-generation/run_generation.py \
    --model_type=gpt2 \
    --model_name_or_path=output_gpt2 \
    --prompt "こんにちは。 " \
    --seed=${RANDOM} \
    --length 1000
# Out:
# 2020-09-22 08:58:14.854910: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 09/22/2020 08:58:17 - WARNING - __main__ -   device: cuda, n_gpu: 1, 16-bits training: False
# 09/22/2020 08:58:27 - INFO - __main__ -   Namespace(device=device(type='cuda'), fp16=False, k=0, length=1000, model_name_or_path='output_gpt2', model_type='gpt2', n_gpu=1, no_cuda=False, num_return_sequences=1, p=0.9, padding_text='', prefix='', prompt='こんにちは。 ', repetition_penalty=1.0, seed=31972, stop_token=None, temperature=1.0, xlm_language='')
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# === GENERATED SEQUENCE 1 ===
# こんにちは。  いろいろ
# 本当にまだまだって
# 私にお話しようとかを
# 本当にありがとう(´ω`)
#
#
# 本当にありがとうございます！
# 皆さんものスペシャルで
# なってここんな感じ。
#
#
#
# ちなみに！お楽しみに
# お話したみは来てくださいね！
#
# 今週もこの夜遠極せだな～
#
#
#
#
#
#
#
# 明日はまいちゅんカフェ！
# ラジオの終わりしていたら
# オーディションも楽しかったです。
#
#
# 今週も明日を作りました。
# これはパフォーマンスやろうに！
#
# コメントというから
# いろいろ早いて
# 見られるかな～？？
#
# ...
